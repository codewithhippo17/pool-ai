# %%
# %run ex01/array.py
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'dict'>
# <class 'list'>
# <class 'tuple'>
# <class 'set'>
# <class 'bool'>

# %%
type(my_array)
# Out:
# numpy.ndarray
